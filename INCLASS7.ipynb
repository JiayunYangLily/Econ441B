# %%
pip install openai wikipedia
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=cbc4d2d47ca00de291892e6b622b07c58e02e24393d6e404e02712ada4e7c376
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %%
import openai
import os
import wikipedia

# %% [markdown]
# # 1.) Set up OpenAI and the enviornment

# %%
apikey = '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'

# %%
client = openai.OpenAI(
    api_key = apikey
)

# %% [markdown]
# # 2.) Use the wikipedia api to get a function that pulls in the text of a wikipedia page

# %%
page_titles = ['Artificial Intelligence', 'UCLA']

# %%
page_title = page_titles[0]

# %%
# page.content
def get_wikipedia_content(page_title):
    search_results = wikipedia.search(page_title)
    page = wikipedia.page(search_results[0])
    return(page.content)

# %%
content = get_wikipedia_content(page_title)

# %% [markdown]
# # 3.) Build a chatgpt bot that will analyze the text given and try to locate any false info

# %%
chat_completions = client.chat.completions.create(
    model = 'gpt-4',
    messages = [
        {'role': 'system', 'content': 'I will be giving you an article. I am looking for false information.\
        I want to capture all potentially false info, if there is even small potential for it to be wrong,\
         please return it. PleaseIf there is no false information only return Done!'},
        {'role': 'user', 'content': content[:8180]}]
)

# %%
chat_completions.choices[0].message.content
# Out:
# '1. "Alan Turing was the first person to conduct substantial research in the field that he called machine intelligence." - This statement might be misleading. While Alan Turing was a pioneer in the field, it would be incorrect to say he was the first person to conduct substantial research in machine intelligence. Other researchers, like Warren McCullough and Walter Pitts, were also substantially contributing to the field around the same time.\n\n2. "The space of possible future actions and situations is typically intractably large, so the agents must take actions and evaluate situations while being uncertain what the outcome will be." - While it\'s true that the action space can be large making it challenging for the agents, modern AI systems have techniques like Monte Carlo Tree Search, Pruning & Alpha-Beta pruning, or use of heuristics that can efficiently deal with this issue. It\'s not always the case that agents are working with complete uncertainty about the outcome of their ac
# ...

# %%
def chatgpt_error_correction(test):
    chat_completions = client.chat.completions.create(
    model = 'gpt-4',
    messages = [
        {'role': 'system', 'content': 'I will be giving you an article. I am looking for false information.\
        I want to capture all potentially false info, if there is even small potential for it to be wrong,\
         please return it. PleaseIf there is no false information only return Done!'},
        {'role': 'user', 'content': content[:8180]}]
    )
    print(chat_completions.choices[0].message.content)

# %% [markdown]
# # 4.) Make a for loop and check a few wikipedia pages and return a report of any potentially false info via wikipedia

# %%
page_titles = ['Artificial Intelligence', 'UCLA', 'Rain']

# %%
for page_title in page_titles:
    try:
        print('________' + page_title)
        content = get_wikipedia_content(page_title)
        chatgpt_error_correction(content)
    except:
        print('ERROR')
# Out:
# ________Artificial Intelligence
# "Alan Turing was the first person to conduct substantial research in the field that he called machine intelligence." Alan Turing conducted significant research into what we now call artificial intelligence, but whether or not he was the first to conduct "substantial" research could be seen as subjective, as others may have also contributed significantly to the field.
# "Funding and interest vastly increased after 2012 when deep learning surpassed all previous AI techniques, and after 2017 with the transformer architecture." While there's no doubt that both deep learning and transformer architectures have significantly pushed the field forward, the claim that they "surpassed all previous AI techniques" could be seen as an overstatement or subjective, as other AI techniques are still in use and continue to have value.
# ...
